# %%
# -*- coding: utf-8 -*-

import os
import json
import random
from pathlib import Path
from typing import Dict

from mmengine.config import Config
from mmengine.runner import Runner
from mmdet.utils import register_all_modules

# -----------------------
# 고정 경로
# -----------------------

MMD_ROOT = Path("/data/ephemeral/home/model/baseline/mmdetection")

FULL_DATA_ROOT = Path("/data/ephemeral/home/model/dataset")
TRAIN_JSON_FULL = FULL_DATA_ROOT / "train.json"
TEST_JSON_FULL  = FULL_DATA_ROOT / "test.json"

# 학습 산출물 저장 위치를 명확히 고정
WORK_DIR = Path("/data/ephemeral/home/model/work_dirs_single")
WORK_DIR.mkdir(parents=True, exist_ok=True)

# 이미지 스케일
IMAGE_SCALE = (1024, 1024)

# 클래스
CLASSES = (
    "General trash",
    "Paper",
    "Paper pack",
    "Metal",
    "Glass",
    "Plastic",
    "Styrofoam",
    "Plastic bag",
    "Battery",
    "Clothing",
)

# 기본 실험 이름
EXP_NAME = "cascade_rcnn_r50_1024_single"

# split 비율
TRAIN_RATIO = 0.85  # 0.8/0.2보다 조금 더 학습 데이터에 힘을 실음
RANDOM_SEED = 42

print("MMD_ROOT:", MMD_ROOT)
print("TRAIN_JSON_FULL:", TRAIN_JSON_FULL)
print("TEST_JSON_FULL :", TEST_JSON_FULL)
print("WORK_DIR:", WORK_DIR)
# Out:
# MMD_ROOT: /data/ephemeral/home/model/baseline/mmdetection
# TRAIN_JSON_FULL: /data/ephemeral/home/model/dataset/train.json
# TEST_JSON_FULL : /data/ephemeral/home/model/dataset/test.json
# WORK_DIR: /data/ephemeral/home/model/work_dirs_single

# %%
def load_coco(json_path: Path) -> Dict:
    with open(json_path, "r") as f:
        return json.load(f)

def save_coco(data: Dict, json_path: Path) -> None:
    json_path.parent.mkdir(parents=True, exist_ok=True)
    with open(json_path, "w") as f:
        json.dump(data, f)

def make_train_val_split(
    src_json: Path,
    out_dir: Path,
    train_ratio: float = 0.85,
    seed: int = 42
) -> Dict[str, Path]:
    """
    COCO train.json을 이미지 id 기준으로 랜덤 분할.
    detection에서는 이미지 단위 분할이 가장 기본적이고 안전함.
    """
    random.seed(seed)

    data = load_coco(src_json)
    images = data["images"]
    anns = data["annotations"]

    img_ids = [img["id"] for img in images]
    random.shuffle(img_ids)

    split_idx = int(len(img_ids) * train_ratio)
    train_ids = set(img_ids[:split_idx])
    val_ids   = set(img_ids[split_idx:])

    def _filter(ids: set):
        imgs = [img for img in images if img["id"] in ids]
        img_set = {img["id"] for img in imgs}
        filtered_anns = [ann for ann in anns if ann["image_id"] in img_set]
        return {**data, "images": imgs, "annotations": filtered_anns}

    out_dir.mkdir(parents=True, exist_ok=True)
    train_json = out_dir / "train_split.json"
    val_json   = out_dir / "val_split.json"

    save_coco(_filter(train_ids), train_json)
    save_coco(_filter(val_ids), val_json)

    return {"train": train_json, "val": val_json}

# %%
def set_img_scale(pipeline, scale):
    """
    Resize / RandomResize / RandomChoiceResize 등 스케일을 1024로 통일.
    """
    for t in pipeline:
        if isinstance(t, list):
            set_img_scale(t, scale)
            continue
        if not isinstance(t, dict):
            continue

        if t.get("type") in ("Resize", "RandomResize", "RandomChoiceResize"):
            if "scale" in t:
                t["scale"] = scale
            if "img_scale" in t:
                t["img_scale"] = scale
            if "scales" in t:
                t["scales"] = [scale]

        if "transforms" in t:
            set_img_scale(t["transforms"], scale)

def set_num_classes(model_cfg, num_classes: int):
    """
    bbox_head/roi_head 내부의 num_classes를 재귀적으로 10으로 고정.
    """
    if isinstance(model_cfg, dict):
        if "num_classes" in model_cfg:
            model_cfg["num_classes"] = num_classes
        for v in model_cfg.values():
            set_num_classes(v, num_classes)
    elif isinstance(model_cfg, list):
        for v in model_cfg:
            set_num_classes(v, num_classes)

# %%
def build_cascade_cfg(split_json: Dict[str, Path]) -> Config:
    """
    Cascade R-CNN 단일 모델 학습용 cfg 구성.
    """
    register_all_modules(init_default_scope=True)

    base_cfg_rel = "configs/cascade_rcnn/cascade-rcnn_r50_fpn_1x_coco.py"
    base_cfg_path = MMD_ROOT / base_cfg_rel

    if not base_cfg_path.exists():
        raise FileNotFoundError(f"base config 없음: {base_cfg_path}")

    cfg = Config.fromfile(str(base_cfg_path))
    cfg.default_scope = "mmdet"

    # 데이터 루트
    cfg.data_root = str(FULL_DATA_ROOT)

    # train/val dataset 교체
    for key, ann_path in [
        ("train_dataloader", split_json["train"]),
        ("val_dataloader", split_json["val"]),
    ]:
        loader = cfg[key]
        ds_cfg = loader["dataset"] if "dataset" in loader else loader

        ds_cfg.metainfo = dict(classes=CLASSES)
        ds_cfg.data_root = str(FULL_DATA_ROOT)

        # ann_file은 절대경로로 줘도 안전
        ds_cfg.ann_file = str(ann_path)
        ds_cfg.data_prefix = dict(img="")

    # test_dataloader는 val을 재활용해서 val mAP 계산용으로 사용
    cfg.test_dataloader = cfg.val_dataloader
    cfg.test_evaluator = dict(
        type="CocoMetric",
        ann_file=str(split_json["val"]),
        metric="bbox",
        iou_thrs=[0.5],
        format_only=False,
    )
    # --- [추가] val_evaluator도 반드시 교체해야 COCO 기본 경로 에러가 사라짐 ---
    cfg.val_evaluator = dict(
        type="CocoMetric",
        ann_file=str(split_json["val"]),
        metric="bbox",
        iou_thrs=[0.5],
        format_only=False,
    )

    # 스케일 고정
    set_img_scale(cfg.train_dataloader.dataset.pipeline, IMAGE_SCALE)
    set_img_scale(cfg.val_dataloader.dataset.pipeline, IMAGE_SCALE)

    # 클래스 수 설정
    set_num_classes(cfg.model, len(CLASSES))

    # 배치/워커
    cfg.train_dataloader.batch_size = 2
    cfg.train_dataloader.num_workers = 4
    cfg.val_dataloader.batch_size = 1
    cfg.val_dataloader.num_workers = 2
    cfg.test_dataloader.batch_size = 1
    cfg.test_dataloader.num_workers = 2

    # epoch 확장: 1x보다 약간 길게
    cfg.train_cfg.max_epochs = 12
    cfg.train_cfg.val_interval = 1
    cfg.val_cfg = dict(type="ValLoop")

    # lr 스케일링 (단일 GPU + bs=2 기준 보수적으로)
    base_lr = cfg.optim_wrapper.optimizer.get("lr", 0.02)
    cfg.optim_wrapper.optimizer["lr"] = base_lr * 2 / 16

    # checkpoint/로그 간격
    cfg.default_hooks["checkpoint"]["interval"] = 1
    cfg.default_hooks["checkpoint"]["max_keep_ckpts"] = 2
    cfg.default_hooks["logger"]["interval"] = 50

    # work_dir 고정
    cfg.work_dir = str(WORK_DIR / EXP_NAME)

    # 시드
    cfg.randomness = dict(seed=RANDOM_SEED, deterministic=False)

    return cfg

# %%
# split 생성
split_dir = FULL_DATA_ROOT / "splits_single"
split_json = make_train_val_split(
    src_json=TRAIN_JSON_FULL,
    out_dir=split_dir,
    train_ratio=TRAIN_RATIO,
    seed=RANDOM_SEED
)

print("train split:", split_json["train"])
print("val split  :", split_json["val"])

# cfg 생성
cfg = build_cascade_cfg(split_json)

# 학습
runner = Runner.from_cfg(cfg)
runner.train()

# val mAP50 평가
metrics = runner.test()
print("val metrics:", metrics)

print("학습 완료. work_dir:", cfg.work_dir)
# Out:
# train split: /data/ephemeral/home/model/dataset/splits_single/train_split.json
# val split  : /data/ephemeral/home/model/dataset/splits_single/val_split.json
# 12/06 06:58:15 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 42
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: n/a
#     PyTorch: 2.1.2+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.2+cu121
#     OpenCV: 4.7.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 42
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
# /bin/sh: 1: gcc: not found
# 12/06 06:58:15 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = '/data/ephemeral/home/model/dataset'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(interval=1, max_keep_ckpts=2, type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=10,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=10,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=10,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='CascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='CascadeRCNN')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# randomness = dict(deterministic=False, seed=42)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file=
#         '/data/ephemeral/home/model/dataset/splits_single/val_split.json',
#         backend_args=None,
#         data_prefix=dict(img=''),
#         data_root='/data/ephemeral/home/model/dataset',
#         metainfo=dict(
#             classes=(
#                 'General trash',
#                 'Paper',
#                 'Paper pack',
#                 'Metal',
#                 'Glass',
#                 'Plastic',
#                 'Styrofoam',
#                 'Plastic bag',
#                 'Battery',
#                 'Clothing',
#             )),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='/data/ephemeral/home/model/dataset/splits_single/val_split.json',
#     format_only=False,
#     iou_thrs=[
#         0.5,
#     ],
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=12, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file=
#         '/data/ephemeral/home/model/dataset/splits_single/train_split.json',
#         backend_args=None,
#         data_prefix=dict(img=''),
#         data_root='/data/ephemeral/home/model/dataset',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'General trash',
#                 'Paper',
#                 'Paper pack',
#                 'Metal',
#                 'Glass',
#                 'Plastic',
#                 'Styrofoam',
#                 'Plastic bag',
#                 'Battery',
#                 'Clothing',
#             )),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file=
#         '/data/ephemeral/home/model/dataset/splits_single/val_split.json',
#         backend_args=None,
#         data_prefix=dict(img=''),
#         data_root='/data/ephemeral/home/model/dataset',
#         metainfo=dict(
#             classes=(
#                 'General trash',
#                 'Paper',
#                 'Paper pack',
#                 'Metal',
#                 'Glass',
#                 'Plastic',
#                 'Styrofoam',
#                 'Plastic bag',
#                 'Battery',
#                 'Clothing',
#             )),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='/data/ephemeral/home/model/dataset/splits_single/val_split.json',
#     format_only=False,
#     iou_thrs=[
#         0.5,
#     ],
#     metric='bbox',
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/data/ephemeral/home/model/work_dirs_single/cascade_rcnn_r50_1024_single'
#
# 12/06 06:58:17 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 12/06 06:58:17 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 12/06 06:58:18 - mmengine - INFO - load model from: torchvision://resnet50
# 12/06 06:58:18 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# 12/06 06:58:18 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 12/06 06:58:18 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 12/06 06:58:18 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 12/06 06:58:18 - mmengine - INFO - Checkpoints will be saved to /data/ephemeral/home/model/work_dirs_single/cascade_rcnn_r50_1024_single.
# 12/06 06:58:34 - mmengine - INFO - Epoch(train)  [1][  50/2075]  lr: 2.4775e-04  eta: 2:08:13  time: 0.3096  data_time: 0.0088  memory: 3953  loss: 2.3182  loss_rpn_cls: 0.6122  loss_rpn_bbox: 0.0501  s0.loss_cls: 0.8669  s0.acc: 91.2109  s0.loss_bbox: 0.0374  s1.loss_cls: 0.4791  s1.acc: 96.1914  s1.loss_bbox: 0.0084  s2.loss_cls: 0.2631  s2.acc: 98.0469  s2.loss_bbox: 0.0010
# 12/06 06:58:48 - mmengine - INFO - Epoch(train)  [1][ 100/2075]  lr: 4.9800e-04  eta: 2:01:53  time: 0.2802  data_time: 0.0054  memory: 3953  loss: 0.8521  loss_rpn_cls: 0.1860  loss_rpn_bbox: 0.0438  s0.loss_cls: 0.3237  s0.acc: 93.5547  s0.loss_bbox: 0.1276  s1.loss_cls: 0.0970  s1.acc: 97.2656  s1.loss_bbox: 0.0370  s2.loss_cls: 0.0315  s2.acc: 98.5352  s2.loss_bbox: 0.0054
# 12/06 06:59:02 - mmengine - INFO - Epoch(train)  [1][ 150/2075]  lr: 7.4825e-04  eta: 1:59:32  time: 0.2796  data_time: 0.0056  memory: 3953  loss: 0.6342  loss_rpn_cls: 0.0932  loss_rpn_bbox: 0.0309  s0.loss_cls: 0.2552  s0.acc: 93.7500  s0.loss_bbox: 0.1207  s1.loss_cls: 0.0705  s1.acc: 97.1680  s1.loss_bbox: 0.0365  s2.loss_cls: 0.0215  s2.acc: 98.8281  s2.loss_bbox: 0.0056
# 12/06 06:59:16 - mmengine - INFO - Epoch(train)  [1][ 200/2075]  lr: 9.9850e-04  eta: 1:58:23  time: 0.2810  data_time: 0.0058  memory: 3953  loss: 0.7635  loss_rpn_cls: 0.1102  loss_rpn_bbox: 0.0439  s0.loss_cls: 0.3054  s0.acc: 98.1445  s0.loss_bbox: 0.1425  s1.loss_cls: 0.0853  s1.acc: 99.3164  s1.loss_bbox: 0.0429  s2.loss_cls: 0.0268  s2.acc: 99.7070  s2.loss_bbox: 0.0065
# 12/06 06:59:30 - mmengine - INFO - Epoch(train)  [1][ 250/2075]  lr: 1.2487e-03  eta: 1:57:31  time: 0.2799  data_time: 0.0052  memory: 3952  loss: 0.7745  loss_rpn_cls: 0.0939  loss_rpn_bbox: 0.0375  s0.loss_cls: 0.3161  s0.acc: 89.6484  s0.loss_bbox: 0.1509  s1.loss_cls: 0.0908  s1.acc: 95.9961  s1.loss_bbox: 0.0520  s2.loss_cls: 0.0263  s2.acc: 98.0469  s2.loss_bbox: 0.0070
# 12/06 06:59:44 - mmengine - INFO - Epoch(train)  [1][ 300/2075]  lr: 1.4990e-03  eta: 1:56:52  time: 0.2800  data_time: 0.0055  memory: 3952  loss: 0.9335  loss_rpn_cls: 0.1077  loss_rpn_bbox: 0.0486  s0.loss_cls: 0.3748  s0.acc: 96.4844  s0.loss_bbox: 0.1804  s1.loss_cls: 0.1120  s1.acc: 98.2422  s1.loss_bbox: 0.0665  s2.loss_cls: 0.0331  s2.acc: 99.0234  s2.loss_bbox: 0.0105
# 12/06 06:59:58 - mmengine - INFO - Epoch(train)  [1][ 350/2075]  lr: 1.7492e-03  eta: 1:56:26  time: 0.2819  data_time: 0.0056  memory: 3953  loss: 0.8734  loss_rpn_cls: 0.0773  loss_rpn_bbox: 0.0338  s0.loss_cls: 0.3566  s0.acc: 92.3828  s0.loss_bbox: 0.1737  s1.loss_cls: 0.1121  s1.acc: 95.1172  s1.loss_bbox: 0.0756  s2.loss_cls: 0.0312  s2.acc: 98.0469  s2.loss_bbox: 0.0131
# 12/06 07:00:12 - mmengine - INFO - Epoch(train)  [1][ 400/2075]  lr: 1.9995e-03  eta: 1:56:01  time: 0.2809  data_time: 0.0054  memory: 3953  loss: 0.9023  loss_rpn_cls: 0.1014  loss_rpn_bbox: 0.0426  s0.loss_cls: 0.3778  s0.acc: 95.6055  s0.loss_bbox: 0.1652  s1.loss_cls: 0.1078  s1.acc: 98.2422  s1.loss_bbox: 0.0654  s2.loss_cls: 0.0309  s2.acc: 99.2188  s2.loss_bbox: 0.0111
# 12/06 07:00:26 - mmengine - INFO - Epoch(train)  [1][ 450/2075]  lr: 2.2497e-03  eta: 1:55:39  time: 0.2814  data_time: 0.0055  memory: 3953  loss: 0.8536  loss_rpn_cls: 0.0987  loss_rpn_bbox: 0.0508  s0.loss_cls: 0.3389  s0.acc: 85.8398  s0.loss_bbox: 0.1706  s1.loss_cls: 0.0978  s1.acc: 93.7500  s1.loss_bbox: 0.0570  s2.loss_cls: 0.0300  s2.acc: 96.4844  s2.loss_bbox: 0.0099
# 12/06 07:00:40 - mmengine - INFO - Epoch(train)  [1][ 500/2075]  lr: 2.5000e-03  eta: 1:55:17  time: 0.2805  data_time: 0.0054  memory: 3953  loss: 0.8515  loss_rpn_cls: 0.0819  loss_rpn_bbox: 0.0366  s0.loss_cls: 0.3599  s0.acc: 88.3789  s0.loss_bbox: 0.1583  s1.loss_cls: 0.1045  s1.acc: 93.2617  s1.loss_bbox: 0.0689  s2.loss_cls: 0.0292  s2.acc: 97.2656  s2.loss_bbox: 0.0121
# 12/06 07:00:54 - mmengine - INFO - Epoch(train)  [1][ 550/2075]  lr: 2.5000e-03  eta: 1:54:55  time: 0.2798  data_time: 0.0054  memory: 3953  loss: 0.8102  loss_rpn_cls: 0.0740  loss_rpn_bbox: 0.0436  s0.loss_cls: 0.3279  s0.acc: 95.5078  s0.loss_bbox: 0.1359  s1.loss_cls: 0.1111  s1.acc: 95.6055  s1.loss_bbox: 0.0701  s2.loss_cls: 0.0333  s2.acc: 97.6562  s2.loss_bbox: 0.0144
# 12/06 07:01:08 - mmengine - INFO - Epoch(train)  [1][ 600/2075]  lr: 2.5000e-03  eta: 1:54:34  time: 0.2798  data_time: 0.0053  memory: 3952  loss: 0.9012  loss_rpn_cls: 0.0821  loss_rpn_bbox: 0.0443  s0.loss_cls: 0.3499  s0.acc: 98.1445  s0.loss_bbox: 0.1592  s1.loss_cls: 0.1230  s1.acc: 97.8516  s1.loss_bbox: 0.0850  s2.loss_cls: 0.0384  s2.acc: 98.2422  s2.loss_bbox: 0.0193
# 12/06 07:01:22 - mmengine - INFO - Epoch(train)  [1][ 650/2075]  lr: 2.5000e-03  eta: 1:54:17  time: 0.2815  data_time: 0.0055  memory: 3952  loss: 1.0670  loss_rpn_cls: 0.0800  loss_rpn_bbox: 0.0443  s0.loss_cls: 0.4003  s0.acc: 91.5039  s0.loss_bbox: 0.1949  s1.loss_cls: 0.1533  s1.acc: 92.5781  s1.loss_bbox: 0.1163  s2.loss_cls: 0.0494  s2.acc: 94.7266  s2.loss_bbox: 0.0285
# 12/06 07:01:36 - mmengine - INFO - Epoch(train)  [1][ 700/2075]  lr: 2.5000e-03  eta: 1:53:58  time: 0.2800  data_time: 0.0055  memory: 3953  loss: 0.9186  loss_rpn_cls: 0.0740  loss_rpn_bbox: 0.0344  s0.loss_cls: 0.3400  s0.acc: 86.3281  s0.loss_bbox: 0.1629  s1.loss_cls: 0.1333  s1.acc: 88.2812  s1.loss_bbox: 0.1023  s2.loss_cls: 0.0439  s2.acc: 91.2109  s2.loss_bbox: 0.0278
# 12/06 07:01:50 - mmengine - INFO - Epoch(train)  [1][ 750/2075]  lr: 2.5000e-03  eta: 1:53:40  time: 0.2804  data_time: 0.0053  memory: 3953  loss: 0.9592  loss_rpn_cls: 0.0780  loss_rpn_bbox: 0.0414  s0.loss_cls: 0.3429  s0.acc: 87.9883  s0.loss_bbox: 0.1739  s1.loss_cls: 0.1335  s1.acc: 90.5273  s1.loss_bbox: 0.1106  s2.loss_cls: 0.0462  s2.acc: 93.4570  s2.loss_bbox: 0.0326
# 12/06 07:02:04 - mmengine - INFO - Epoch(train)  [1][ 800/2075]  lr: 2.5000e-03  eta: 1:53:24  time: 0.2810  data_time: 0.0052  memory: 3953  loss: 0.9840  loss_rpn_cls: 0.0892  loss_rpn_bbox: 0.0419  s0.loss_cls: 0.3628  s0.acc: 94.0430  s0.loss_bbox: 0.1698  s1.loss_cls: 0.1401  s1.acc: 96.1914  s1.loss_bbox: 0.1005  s2.loss_cls: 0.0497  s2.acc: 97.6562  s2.loss_bbox: 0.0299
# 12/06 07:02:18 - mmengine - INFO - Epoch(train)  [1][ 850/2075]  lr: 2.5000e-03  eta: 1:53:07  time: 0.2799  data_time: 0.0055  memory: 3953  loss: 0.8781  loss_rpn_cls: 0.0657  loss_rpn_bbox: 0.0371  s0.loss_cls: 0.3182  s0.acc: 96.7773  s0.loss_bbox: 0.1461  s1.loss_cls: 0.1299  s1.acc: 97.7539  s1.loss_bbox: 0.1000  s2.loss_cls: 0.0477  s2.acc: 98.2422  s2.loss_bbox: 0.0333
# 12/06 07:02:32 - mmengine - INFO - Epoch(train)  [1][ 900/2075]  lr: 2.5000e-03  eta: 1:52:50  time: 0.2801  data_time: 0.0055  memory: 3953  loss: 0.9262  loss_rpn_cls: 0.0922  loss_rpn_bbox: 0.0396  s0.loss_cls: 0.3474  s0.acc: 97.5586  s0.loss_bbox: 0.1521  s1.loss_cls: 0.1308  s1.acc: 99.2188  s1.loss_bbox: 0.0906  s2.loss_cls: 0.0458  s2.acc: 99.4141  s2.loss_bbox: 0.0278
# 12/06 07:02:46 - mmengine - INFO - Epoch(train)  [1][ 950/2075]  lr: 2.5000e-03  eta: 1:52:33  time: 0.2801  data_time: 0.0056  memory: 3953  loss: 0.9190  loss_rpn_cls: 0.0607  loss_rpn_bbox: 0.0339  s0.loss_cls: 0.3510  s0.acc: 84.1797  s0.loss_bbox: 0.1597  s1.loss_cls: 0.1358  s1.acc: 85.5469  s1.loss_bbox: 0.0988  s2.loss_cls: 0.0472  s2.acc: 89.1602  s2.loss_bbox: 0.0318
# 12/06 07:03:00 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20251206_065814
# 12/06 07:03:00 - mmengine - INFO - Epoch(train)  [1][1000/2075]  lr: 2.5000e-03  eta: 1:52:19  time: 0.2818  data_time: 0.0054  memory: 3953  loss: 0.8614  loss_rpn_cls: 0.0607  loss_rpn_bbox: 0.0375  s0.loss_cls: 0.3014  s0.acc: 94.1406  s0.loss_bbox: 0.1431  s1.loss_cls: 0.1306  s1.acc: 94.5312  s1.loss_bbox: 0.1002  s2.loss_cls: 0.0504  s2.acc: 95.8984  s2.loss_bbox: 0.0376
# 12/06 07:03:14 - mmengine - INFO - Epoch(train)  [1][1050/2075]  lr: 2.5000e-03  eta: 1:52:04  time: 0.2817  data_time: 0.0055  memory: 3953  loss: 0.9888  loss_rpn_cls: 0.0866  loss_rpn_bbox: 0.0492  s0.loss_cls: 0.3396  s0.acc: 85.0586  s0.loss_bbox: 0.1556  s1.loss_cls: 0.1452  s1.acc: 85.6445  s1.loss_bbox: 0.1095  s2.loss_cls: 0.0579  s2.acc: 88.9648  s2.loss_bbox: 0.0451
# 12/06 07:03:28 - mmengine - INFO - Epoch(train)  [1][1100/2075]  lr: 2.5000e-03  eta: 1:51:48  time: 0.2804  data_time: 0.0054  memory: 3953  loss: 0.9573  loss_rpn_cls: 0.0705  loss_rpn_bbox: 0.0367  s0.loss_cls: 0.3495  s0.acc: 81.5430  s0.loss_bbox: 0.1448  s1.loss_cls: 0.1499  s1.acc: 87.9883  s1.loss_bbox: 0.1071  s2.loss_cls: 0.0566  s2.acc: 92.0898  s2.loss_bbox: 0.0423
# 12/06 07:03:42 - mmengine - INFO - Epoch(train)  [1][1150/2075]  lr: 2.5000e-03  eta: 1:51:34  time: 0.2811  data_time: 0.0053  memory: 3953  loss: 0.8947  loss_rpn_cls: 0.0522  loss_rpn_bbox: 0.0348  s0.loss_cls: 0.3232  s0.acc: 92.5781  s0.loss_bbox: 0.1487  s1.loss_cls: 0.1380  s1.acc: 94.0430  s1.loss_bbox: 0.1050  s2.loss_cls: 0.0533  s2.acc: 96.5820  s2.loss_bbox: 0.0396
# 12/06 07:03:56 - mmengine - INFO - Epoch(train)  [1][1200/2075]  lr: 2.5000e-03  eta: 1:51:18  time: 0.2800  data_time: 0.0052  memory: 3953  loss: 0.8125  loss_rpn_cls: 0.0575  loss_rpn_bbox: 0.0283  s0.loss_cls: 0.2823  s0.acc: 93.0664  s0.loss_bbox: 0.1345  s1.loss_cls: 0.1221  s1.acc: 95.0195  s1.loss_bbox: 0.0950  s2.loss_cls: 0.0506  s2.acc: 95.2148  s2.loss_bbox: 0.0422
# 12/06 07:04:11 - mmengine - INFO - Epoch(train)  [1][1250/2075]  lr: 2.5000e-03  eta: 1:51:04  time: 0.2821  data_time: 0.0057  memory: 3953  loss: 0.9827  loss_rpn_cls: 0.0661  loss_rpn_bbox: 0.0405  s0.loss_cls: 0.3499  s0.acc: 96.1914  s0.loss_bbox: 0.1589  s1.loss_cls: 0.1510  s1.acc: 95.5078  s1.loss_bbox: 0.1119  s2.loss_cls: 0.0598  s2.acc: 95.8984  s2.loss_bbox: 0.0445
# 12/06 07:04:25 - mmengine - INFO - Epoch(train)  [1][1300/2075]  lr: 2.5000e-03  eta: 1:50:50  time: 0.2823  data_time: 0.0054  memory: 3953  loss: 0.9147  loss_rpn_cls: 0.0690  loss_rpn_bbox: 0.0298  s0.loss_cls: 0.3249  s0.acc: 92.4805  s0.loss_bbox: 0.1419  s1.loss_cls: 0.1390  s1.acc: 91.6992  s1.loss_bbox: 0.1062  s2.loss_cls: 0.0567  s2.acc: 91.7969  s2.loss_bbox: 0.0471
# 12/06 07:04:39 - mmengine - INFO - Epoch(train)  [1][1350/2075]  lr: 2.5000e-03  eta: 1:50:36  time: 0.2817  data_time: 0.0054  memory: 3953  loss: 1.1510  loss_rpn_cls: 0.0781  loss_rpn_bbox: 0.0496  s0.loss_cls: 0.4120  s0.acc: 91.2109  s0.loss_bbox: 0.1868  s1.loss_cls: 0.1753  s1.acc: 90.9180  s1.loss_bbox: 0.1297  s2.loss_cls: 0.0686  s2.acc: 92.7734  s2.loss_bbox: 0.0508
# 12/06 07:04:53 - mmengine - INFO - Epoch(train)  [1][1400/2075]  lr: 2.5000e-03  eta: 1:50:23  time: 0.2827  data_time: 0.0054  memory: 3953  loss: 0.9554  loss_rpn_cls: 0.0574  loss_rpn_bbox: 0.0392  s0.loss_cls: 0.3294  s0.acc: 83.9844  s0.loss_bbox: 0.1620  s1.loss_cls: 0.1435  s1.acc: 87.1094  s1.loss_bbox: 0.1182  s2.loss_cls: 0.0568  s2.acc: 90.1367  s2.loss_bbox: 0.0488
# 12/06 07:05:07 - mmengine - INFO - Epoch(train)  [1][1450/2075]  lr: 2.5000e-03  eta: 1:50:09  time: 0.2823  data_time: 0.0055  memory: 3953  loss: 1.0570  loss_rpn_cls: 0.0821  loss_rpn_bbox: 0.0453  s0.loss_cls: 0.3786  s0.acc: 85.7422  s0.loss_bbox: 0.1637  s1.loss_cls: 0.1606  s1.acc: 87.5977  s1.loss_bbox: 0.1193  s2.loss_cls: 0.0606  s2.acc: 91.3086  s2.loss_bbox: 0.0467
# 12/06 07:05:21 - mmengine - INFO - Epoch(train)  [1][1500/2075]  lr: 2.5000e-03  eta: 1:49:54  time: 0.2809  data_time: 0.0057  memory: 3953  loss: 1.1154  loss_rpn_cls: 0.0768  loss_rpn_bbox: 0.0431  s0.loss_cls: 0.4011  s0.acc: 94.1406  s0.loss_bbox: 0.1825  s1.loss_cls: 0.1691  s1.acc: 94.8242  s1.loss_bbox: 0.1282  s2.loss_cls: 0.0647  s2.acc: 96.9727  s2.loss_bbox: 0.0499
# 12/06 07:05:35 - mmengine - INFO - Epoch(train)  [1][1550/2075]  lr: 2.5000e-03  eta: 1:49:41  time: 0.2827  data_time: 0.0053  memory: 3953  loss: 1.0258  loss_rpn_cls: 0.0615  loss_rpn_bbox: 0.0377  s0.loss_cls: 0.3564  s0.acc: 85.9375  s0.loss_bbox: 0.1699  s1.loss_cls: 0.1560  s1.acc: 90.8203  s1.loss_bbox: 0.1270  s2.loss_cls: 0.0630  s2.acc: 94.7266  s2.loss_bbox: 0.0542
# 12/06 07:05:49 - mmengine - INFO - Epoch(train)  [1][1600/2075]  lr: 2.5000e-03  eta: 1:49:26  time: 0.2816  data_time: 0.0056  memory: 3952  loss: 0.8548  loss_rpn_cls: 0.0478  loss_rpn_bbox: 0.0314  s0.loss_cls: 0.2970  s0.acc: 94.2383  s0.loss_bbox: 0.1389  s1.loss_cls: 0.1335  s1.acc: 93.0664  s1.loss_bbox: 0.1076  s2.loss_cls: 0.0534  s2.acc: 94.8242  s2.loss_bbox: 0.0452
# 12/06 07:06:03 - mmengine - INFO - Epoch(train)  [1][1650/2075]  lr: 2.5000e-03  eta: 1:49:12  time: 0.2810  data_time: 0.0055  memory: 3953  loss: 0.9476  loss_rpn_cls: 0.0669  loss_rpn_bbox: 0.0426  s0.loss_cls: 0.3237  s0.acc: 98.0469  s0.loss_bbox: 0.1476  s1.loss_cls: 0.1448  s1.acc: 98.1445  s1.loss_bbox: 0.1168  s2.loss_cls: 0.0576  s2.acc: 98.2422  s2.loss_bbox: 0.0475
# 12/06 07:06:17 - mmengine - INFO - Epoch(train)  [1][1700/2075]  lr: 2.5000e-03  eta: 1:48:57  time: 0.2812  data_time: 0.0056  memory: 3953  loss: 0.9269  loss_rpn_cls: 0.0464  loss_rpn_bbox: 0.0362  s0.loss_cls: 0.3165  s0.acc: 88.8672  s0.loss_bbox: 0.1552  s1.loss_cls: 0.1453  s1.acc: 90.6250  s1.loss_bbox: 0.1158  s2.loss_cls: 0.0604  s2.acc: 92.4805  s2.loss_bbox: 0.0512
# 12/06 07:06:31 - mmengine - INFO - Epoch(train)  [1][1750/2075]  lr: 2.5000e-03  eta: 1:48:42  time: 0.2802  data_time: 0.0053  memory: 3953  loss: 0.9714  loss_rpn_cls: 0.0613  loss_rpn_bbox: 0.0362  s0.loss_cls: 0.3376  s0.acc: 93.6523  s0.loss_bbox: 0.1492  s1.loss_cls: 0.1520  s1.acc: 94.6289  s1.loss_bbox: 0.1159  s2.loss_cls: 0.0647  s2.acc: 92.6758  s2.loss_bbox: 0.0544
# 12/06 07:06:45 - mmengine - INFO - Epoch(train)  [1][1800/2075]  lr: 2.5000e-03  eta: 1:48:28  time: 0.2814  data_time: 0.0058  memory: 3952  loss: 0.8039  loss_rpn_cls: 0.0485  loss_rpn_bbox: 0.0329  s0.loss_cls: 0.2725  s0.acc: 95.8008  s0.loss_bbox: 0.1150  s1.loss_cls: 0.1278  s1.acc: 95.8984  s1.loss_bbox: 0.0994  s2.loss_cls: 0.0573  s2.acc: 94.7266  s2.loss_bbox: 0.0506
# 12/06 07:07:00 - mmengine - INFO - Epoch(train)  [1][1850/2075]  lr: 2.5000e-03  eta: 1:48:13  time: 0.2814  data_time: 0.0056  memory: 3953  loss: 0.8471  loss_rpn_cls: 0.0382  loss_rpn_bbox: 0.0205  s0.loss_cls: 0.3052  s0.acc: 98.2422  s0.loss_bbox: 0.1264  s1.loss_cls: 0.1404  s1.acc: 98.3398  s1.loss_bbox: 0.1064  s2.loss_cls: 0.0586  s2.acc: 98.1445  s2.loss_bbox: 0.0513
# 12/06 07:07:14 - mmengine - INFO - Epoch(train)  [1][1900/2075]  lr: 2.5000e-03  eta: 1:47:59  time: 0.2815  data_time: 0.0055  memory: 3953  loss: 0.9155  loss_rpn_cls: 0.0557  loss_rpn_bbox: 0.0315  s0.loss_cls: 0.3213  s0.acc: 96.3867  s0.loss_bbox: 0.1466  s1.loss_cls: 0.1440  s1.acc: 95.8008  s1.loss_bbox: 0.1119  s2.loss_cls: 0.0583  s2.acc: 94.9219  s2.loss_bbox: 0.0462
# 12/06 07:07:28 - mmengine - INFO - Epoch(train)  [1][1950/2075]  lr: 2.5000e-03  eta: 1:47:44  time: 0.2807  data_time: 0.0053  memory: 3953  loss: 0.9055  loss_rpn_cls: 0.0516  loss_rpn_bbox: 0.0347  s0.loss_cls: 0.3074  s0.acc: 88.4766  s0.loss_bbox: 0.1426  s1.loss_cls: 0.1404  s1.acc: 89.2578  s1.loss_bbox: 0.1169  s2.loss_cls: 0.0592  s2.acc: 91.7969  s2.loss_bbox: 0.0528
# 12/06 07:07:42 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20251206_065814
# 12/06 07:07:42 - mmengine - INFO - Epoch(train)  [1][2000/2075]  lr: 2.5000e-03  eta: 1:47:31  time: 0.2822  data_time: 0.0054  memory: 3953  loss: 0.8830  loss_rpn_cls: 0.0503  loss_rpn_bbox: 0.0305  s0.loss_cls: 0.2978  s0.acc: 96.0938  s0.loss_bbox: 0.1354  s1.loss_cls: 0.1413  s1.acc: 94.8242  s1.loss_bbox: 0.1142  s2.loss_cls: 0.0609  s2.acc: 93.9453  s2.loss_bbox: 0.0527
# 12/06 07:07:56 - mmengine - INFO - Epoch(train)  [1][2050/2075]  lr: 2.5000e-03  eta: 1:47:15  time: 0.2797  data_time: 0.0055  memory: 3953  loss: 0.8137  loss_rpn_cls: 0.0408  loss_rpn_bbox: 0.0248  s0.loss_cls: 0.2796  s0.acc: 86.7188  s0.loss_bbox: 0.1311  s1.loss_cls: 0.1304  s1.acc: 91.5039  s1.loss_bbox: 0.1040  s2.loss_cls: 0.0550  s2.acc: 94.7266  s2.loss_bbox: 0.0480
# 12/06 07:08:03 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20251206_065814
# 12/06 07:08:03 - mmengine - INFO - Saving checkpoint at 1 epochs
# 12/06 07:08:08 - mmengine - INFO - Epoch(val)  [1][ 50/733]    eta: 0:00:43  time: 0.0636  data_time: 0.0049  memory: 3953
# 12/06 07:08:11 - mmengine - INFO - Epoch(val)  [1][100/733]    eta: 0:00:38  time: 0.0581  data_time: 0.0029  memory: 897
# 12/06 07:08:14 - mmengine - INFO - Epoch(val)  [1][150/733]    eta: 0:00:34  time: 0.0580  data_time: 0.0028  memory: 897
# 12/06 07:08:17 - mmengine - INFO - Epoch(val)  [1][200/733]    eta: 0:00:31  time: 0.0590  data_time: 0.0029  memory: 897
# 12/06 07:08:20 - mmengine - INFO - Epoch(val)  [1][250/733]    eta: 0:00:28  time: 0.0583  data_time: 0.0028  memory: 897
# 12/06 07:08:23 - mmengine - INFO - Epoch(val)  [1][300/733]    eta: 0:00:25  time: 0.0583  data_time: 0.0028  memory: 897
# 12/06 07:08:26 - mmengine - INFO - Epoch(val)  [1][350/733]    eta: 0:00:22  time: 0.0585  data_time: 0.0029  memory: 897
# 12/06 07:08:29 - mmengine - INFO - Epoch(val)  [1][400/733]    eta: 0:00:19  time: 0.0591  data_time: 0.0030  memory: 897
# 12/06 07:08:32 - mmengine - INFO - Epoch(val)  [1][450/733]    eta: 0:00:16  time: 0.0585  data_time: 0.0029  memory: 897
# 12/06 07:08:35 - mmengine - INFO - Epoch(val)  [1][500/733]    eta: 0:00:13  time: 0.0590  data_time: 0.0030  memory: 897
# 12/06 07:08:38 - mmengine - INFO - Epoch(val)  [1][550/733]    eta: 0:00:10  time: 0.0583  data_time: 0.0028  memory: 897
# 12/06 07:08:41 - mmengine - INFO - Epoch(val)  [1][600/733]    eta: 0:00:07  time: 0.0593  data_time: 0.0030  memory: 897
# 12/06 07:08:44 - mmengine - INFO - Epoch(val)  [1][650/733]    eta: 0:00:04  time: 0.0587  data_time: 0.0030  memory: 897
# 12/06 07:08:47 - mmengine - INFO - Epoch(val)  [1][700/733]    eta: 0:00:01  time: 0.0586  data_time: 0.0028  memory: 897
# 12/06 07:08:49 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.40s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=300 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=1000 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.099
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.461
# 12/06 07:08:51 - mmengine - INFO - bbox_mAP_copypaste: 0.149 -1.000 -1.000 0.000 0.019 0.187
# 12/06 07:08:51 - mmengine - INFO - Epoch(val) [1][733/733]    coco/bbox_mAP: 0.1490  coco/bbox_mAP_50: -1.0000  coco/bbox_mAP_75: -1.0000  coco/bbox_mAP_s: 0.0000  coco/bbox_mAP_m: 0.0190  coco/bbox_mAP_l: 0.1870  data_time: 0.0030  time: 0.0590
# 12/06 07:09:05 - mmengine - INFO - Epoch(train)  [2][  50/2075]  lr: 2.5000e-03  eta: 1:46:55  time: 0.2841  data_time: 0.0066  memory: 3953  loss: 0.9111  loss_rpn_cls: 0.0499  loss_rpn_bbox: 0.0360  s0.loss_cls: 0.3093  s0.acc: 91.4062  s0.loss_bbox: 0.1370  s1.loss_cls: 0.1487  s1.acc: 92.4805  s1.loss_bbox: 0.1143  s2.loss_cls: 0.0636  s2.acc: 90.9180  s2.loss_bbox: 0.0524
# 12/06 07:09:19 - mmengine - INFO - Epoch(train)  [2][ 100/2075]  lr: 2.5000e-03  eta: 1:46:41  time: 0.2804  data_time: 0.0052  memory: 3953  loss: 0.8869  loss_rpn_cls: 0.0550  loss_rpn_bbox: 0.0325  s0.loss_cls: 0.3061  s0.acc: 92.0898  s0.loss_bbox: 0.1351  s1.loss_cls: 0.1396  s1.acc: 93.4570  s1.loss_bbox: 0.1085  s2.loss_cls: 0.0596  s2.acc: 94.8242  s2.loss_bbox: 0.0504
# 12/06 07:09:33 - mmengine - INFO - Epoch(train)  [2][ 150/2075]  lr: 2.5000e-03  eta: 1:46:27  time: 0.2828  data_time: 0.0052  memory: 3952  loss: 0.9746  loss_rpn_cls: 0.0556  loss_rpn_bbox: 0.0454  s0.loss_cls: 0.3252  s0.acc: 83.5938  s0.loss_bbox: 0.1603  s1.loss_cls: 0.1492  s1.acc: 85.0586  s1.loss_bbox: 0.1256  s2.loss_cls: 0.0620  s2.acc: 89.5508  s2.loss_bbox: 0.0514
# 12/06 07:09:47 - mmengine - INFO - Epoch(train)  [2][ 200/2075]  lr: 2.5000e-03  eta: 1:46:12  time: 0.2804  data_time: 0.0053  memory: 3953  loss: 0.8927  loss_rpn_cls: 0.0466  loss_rpn_bbox: 0.0325  s0.loss_cls: 0.3025  s0.acc: 94.0430  s0.loss_bbox: 0.1363  s1.loss_cls: 0.1459  s1.acc: 92.7734  s1.loss_bbox: 0.1156  s2.loss_cls: 0.0611  s2.acc: 93.7500  s2.loss_bbox: 0.0524
# 12/06 07:10:01 - mmengine - INFO - Epoch(train)  [2][ 250/2075]  lr: 2.5000e-03  eta: 1:45:59  time: 0.2822  data_time: 0.0052  memory: 3953  loss: 0.9113  loss_rpn_cls: 0.0433  loss_rpn_bbox: 0.0304  s0.loss_cls: 0.3173  s0.acc: 86.6211  s0.loss_bbox: 0.1373  s1.loss_cls: 0.1497  s1.acc: 86.4258  s1.loss_bbox: 0.1149  s2.loss_cls: 0.0638  s2.acc: 89.1602  s2.loss_bbox: 0.0545
# 12/06 07:10:15 - mmengine - INFO - Epoch(train)  [2][ 300/2075]  lr: 2.5000e-03  eta: 1:45:44  time: 0.2813  data_time: 0.0053  memory: 3953  loss: 0.9378  loss_rpn_cls: 0.0648  loss_rpn_bbox: 0.0344  s0.loss_cls: 0.3153  s0.acc: 91.4062  s0.loss_bbox: 0.1434  s1.loss_cls: 0.1434  s1.acc: 91.0156  s1.loss_bbox: 0.1185  s2.loss_cls: 0.0619  s2.acc: 91.0156  s2.loss_bbox: 0.0561
# 12/06 07:10:29 - mmengine - INFO - Epoch(train)  [2][ 350/2075]  lr: 2.5000e-03  eta: 1:45:30  time: 0.2816  data_time: 0.0054  memory: 3952  loss: 0.8439  loss_rpn_cls: 0.0398  loss_rpn_bbox: 0.0229  s0.loss_cls: 0.2928  s0.acc: 95.9961  s0.loss_bbox: 0.1188  s1.loss_cls: 0.1415  s1.acc: 95.4102  s1.loss_bbox: 0.1096  s2.loss_cls: 0.0633  s2.acc: 93.3594  s2.loss_bbox: 0.0552
# 12/06 07:10:43 - mmengine - INFO - Epoch(train)  [2][ 400/2075]  lr: 2.5000e-03  eta: 1:45:16  time: 0.2820  data_time: 0.0056  memory: 3953  loss: 0.9934  loss_rpn_cls: 0.0482  loss_rpn_bbox: 0.0300  s0.loss_cls: 0.3432  s0.acc: 96.2891  s0.loss_bbox: 0.1505  s1.loss_cls: 0.1620  s1.acc: 93.9453  s1.loss_bbox: 0.1288  s2.loss_cls: 0.0709  s2.acc: 92.7734  s2.loss_bbox: 0.0599
# 12/06 07:10:57 - mmengine - INFO - Epoch(train)  [2][ 450/2075]  lr: 2.5000e-03  eta: 1:45:02  time: 0.2816  data_time: 0.0051  memory: 3953  loss: 0.9008  loss_rpn_cls: 0.0451  loss_rpn_bbox: 0.0279  s0.loss_cls: 0.3176  s0.acc: 86.6211  s0.loss_bbox: 0.1337  s1.loss_cls: 0.1486  s1.acc: 87.7930  s1.loss_bbox: 0.1102  s2.loss_cls: 0.0645  s2.acc: 92.1875  s2.loss_bbox: 0.0530
# 12/06 07:11:12 - mmengine - INFO - Epoch(train)  [2][ 500/2075]  lr: 2.5000e-03  eta: 1:44:48  time: 0.2814  data_time: 0.0054  memory: 3953  loss: 0.9831  loss_rpn_cls: 0.0531  loss_rpn_bbox: 0.0322  s0.loss_cls: 0.3379  s0.acc: 84.9609  s0.loss_bbox: 0.1479  s1.loss_cls: 0.1590  s1.acc: 86.5234  s1.loss_bbox: 0.1217  s2.loss_cls: 0.0701  s2.acc: 88.5742  s2.loss_bbox: 0.0613
# 12/06 07:11:26 - mmengine - INFO - Epoch(train)  [2][ 550/2075]  lr: 2.5000e-03  eta: 1:44:34  time: 0.2813  data_time: 0.0054  memory: 3953  loss: 1.0797  loss_rpn_cls: 0.0522  loss_rpn_bbox: 0.0388  s0.loss_cls: 0.3619  s0.acc: 91.7969  s0.loss_bbox: 0.1804  s1.loss_cls: 0.1687  s1.acc: 91.5039  s1.loss_bbox: 0.1411  s2.loss_cls: 0.0731  s2.acc: 93.1641  s2.loss_bbox: 0.0635
# 12/06 07:11:40 - mmengine - INFO - Epoch(train)  [2][ 600/2075]  lr: 2.5000e-03  eta: 1:44:19  time: 0.2804  data_time: 0.0051  memory: 3953  loss: 0.8865  loss_rpn_cls: 0.0601  loss_rpn_bbox: 0.0336  s0.loss_cls: 0.2859  s0.acc: 94.6289  s0.loss_bbox: 0.1355  s1.loss_cls: 0.1383  s1.acc: 93.6523  s1.loss_bbox: 0.1173  s2.loss_cls: 0.0606  s2.acc: 94.2383  s2.loss_bbox: 0.0551
# 12/06 07:11:54 - mmengine - INFO - Epoch(train)  [2][ 650/2075]  lr: 2.5000e-03  eta: 1:44:05  time: 0.2819  data_time: 0.0054  memory: 3953  loss: 0.9776  loss_rpn_cls: 0.0529  loss_rpn_bbox: 0.0463  s0.loss_cls: 0.3238  s0.acc: 93.0664  s0.loss_bbox: 0.1505  s1.loss_cls: 0.1535  s1.acc: 92.1875  s1.loss_bbox: 0.1251  s2.loss_cls: 0.0668  s2.acc: 93.2617  s2.loss_bbox: 0.0589
# 12/06 07:12:08 - mmengine - INFO - Epoch(train)  [2][ 700/2075]  lr: 2.5000e-03  eta: 1:43:51  time: 0.2807  data_time: 0.0053  memory: 3953  loss: 0.8325  loss_rpn_cls: 0.0384  loss_rpn_bbox: 0.0310  s0.loss_cls: 0.2940  s0.acc: 92.6758  s0.loss_bbox: 0.1214  s1.loss_cls: 0.1391  s1.acc: 94.3359  s1.loss_bbox: 0.1025  s2.loss_cls: 0.0582  s2.acc: 95.8008  s2.loss_bbox: 0.0478
# 12/06 07:12:22 - mmengine - INFO - Epoch(train)  [2][ 750/2075]  lr: 2.5000e-03  eta: 1:43:37  time: 0.2816  data_time: 0.0053  memory: 3953  loss: 0.8847  loss_rpn_cls: 0.0556  loss_rpn_bbox: 0.0397  s0.loss_cls: 0.2977  s0.acc: 96.3867  s0.loss_bbox: 0.1368  s1.loss_cls: 0.1366  s1.acc: 94.3359  s1.loss_bbox: 0.1085  s2.loss_cls: 0.0588  s2.acc: 94.0430  s2.loss_bbox: 0.0510
# 12/06 07:12:36 - mmengine - INFO - Epoch(train)  [2][ 800/2075]  lr: 2.5000e-03  eta: 1:43:23  time: 0.2820  data_time: 0.0054  memory: 3953  loss: 0.9117  loss_rpn_cls: 0.0481  loss_rpn_bbox: 0.0335  s0.loss_cls: 0.3123  s0.acc: 94.0430  s0.loss_bbox: 0.1399  s1.loss_cls: 0.1425  s1.acc: 95.3125  s1.loss_bbox: 0.1184  s2.loss_cls: 0.0611  s2.acc: 96.0938  s2.loss_bbox: 0.0558
# 12/06 07:12:50 - mmengine - INFO - Epoch(train)  [2][ 850/2075]  lr: 2.5000e-03  eta: 1:43:08  time: 0.2800  data_time: 0.0053  memory: 3953  loss: 0.8119  loss_rpn_cls: 0.0403  loss_rpn_bbox: 0.0247  s0.loss_cls: 0.2789  s0.acc: 98.7305  s0.loss_bbox: 0.1097  s1.loss_cls: 0.1377  s1.acc: 98.3398  s1.loss_bbox: 0.1034  s2.loss_cls: 0.0632  s2.acc: 98.3398  s2.loss_bbox: 0.0540
# 12/06 07:13:04 - mmengine - INFO - Epoch(train)  [2][ 900/2075]  lr: 2.5000e-03  eta: 1:42:54  time: 0.2809  data_time: 0.0051  memory: 3953  loss: 0.8807  loss_rpn_cls: 0.0412  loss_rpn_bbox: 0.0311  s0.loss_cls: 0.3077  s0.acc: 95.8008  s0.loss_bbox: 0.1346  s1.loss_cls: 0.1410  s1.acc: 94.5312  s1.loss_bbox: 0.1097  s2.loss_cls: 0.0618  s2.acc: 92.9688  s2.loss_bbox: 0.0537
# ...
# 12/06 08:58:27 - mmengine - INFO - Epoch(train) [12][ 950/2075]  lr: 2.5000e-05  eta: 0:05:16  time: 0.2819  data_time: 0.0056  memory: 3953  loss: 0.4318  loss_rpn_cls: 0.0107  loss_rpn_bbox: 0.0200  s0.loss_cls: 0.1291  s0.acc: 91.3086  s0.loss_bbox: 0.0754  s1.loss_cls: 0.0575  s1.acc: 91.5916  s1.loss_bbox: 0.0691  s2.loss_cls: 0.0284  s2.acc: 90.3194  s2.loss_bbox: 0.0416
# 12/06 08:58:41 - mmengine - INFO - Epoch(train) [12][1000/2075]  lr: 2.5000e-05  eta: 0:05:02  time: 0.2813  data_time: 0.0054  memory: 3953  loss: 0.4646  loss_rpn_cls: 0.0112  loss_rpn_bbox: 0.0158  s0.loss_cls: 0.1445  s0.acc: 94.0430  s0.loss_bbox: 0.0782  s1.loss_cls: 0.0644  s1.acc: 93.6523  s1.loss_bbox: 0.0726  s2.loss_cls: 0.0322  s2.acc: 95.1172  s2.loss_bbox: 0.0456
# 12/06 08:58:55 - mmengine - INFO - Epoch(train) [12][1050/2075]  lr: 2.5000e-05  eta: 0:04:48  time: 0.2816  data_time: 0.0057  memory: 3954  loss: 0.4392  loss_rpn_cls: 0.0142  loss_rpn_bbox: 0.0196  s0.loss_cls: 0.1269  s0.acc: 96.1914  s0.loss_bbox: 0.0778  s1.loss_cls: 0.0573  s1.acc: 97.9508  s1.loss_bbox: 0.0704  s2.loss_cls: 0.0284  s2.acc: 98.5432  s2.loss_bbox: 0.0445
# 12/06 08:59:09 - mmengine - INFO - Epoch(train) [12][1100/2075]  lr: 2.5000e-05  eta: 0:04:34  time: 0.2816  data_time: 0.0058  memory: 3953  loss: 0.3931  loss_rpn_cls: 0.0114  loss_rpn_bbox: 0.0176  s0.loss_cls: 0.1195  s0.acc: 95.1172  s0.loss_bbox: 0.0641  s1.loss_cls: 0.0525  s1.acc: 95.8984  s1.loss_bbox: 0.0612  s2.loss_cls: 0.0272  s2.acc: 97.2656  s2.loss_bbox: 0.0396
# 12/06 08:59:24 - mmengine - INFO - Epoch(train) [12][1150/2075]  lr: 2.5000e-05  eta: 0:04:20  time: 0.2834  data_time: 0.0056  memory: 3953  loss: 0.4731  loss_rpn_cls: 0.0130  loss_rpn_bbox: 0.0216  s0.loss_cls: 0.1418  s0.acc: 98.7305  s0.loss_bbox: 0.0785  s1.loss_cls: 0.0654  s1.acc: 99.1211  s1.loss_bbox: 0.0732  s2.loss_cls: 0.0335  s2.acc: 99.4141  s2.loss_bbox: 0.0461
# 12/06 08:59:31 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20251206_065814
# 12/06 08:59:38 - mmengine - INFO - Epoch(train) [12][1200/2075]  lr: 2.5000e-05  eta: 0:04:06  time: 0.2821  data_time: 0.0056  memory: 3953  loss: 0.4641  loss_rpn_cls: 0.0140  loss_rpn_bbox: 0.0213  s0.loss_cls: 0.1384  s0.acc: 96.0938  s0.loss_bbox: 0.0783  s1.loss_cls: 0.0626  s1.acc: 97.2656  s1.loss_bbox: 0.0732  s2.loss_cls: 0.0314  s2.acc: 95.1172  s2.loss_bbox: 0.0449
# 12/06 08:59:52 - mmengine - INFO - Epoch(train) [12][1250/2075]  lr: 2.5000e-05  eta: 0:03:52  time: 0.2817  data_time: 0.0056  memory: 3953  loss: 0.4249  loss_rpn_cls: 0.0133  loss_rpn_bbox: 0.0173  s0.loss_cls: 0.1334  s0.acc: 98.6328  s0.loss_bbox: 0.0712  s1.loss_cls: 0.0583  s1.acc: 99.4141  s1.loss_bbox: 0.0629  s2.loss_cls: 0.0283  s2.acc: 99.7070  s2.loss_bbox: 0.0400
# 12/06 09:00:06 - mmengine - INFO - Epoch(train) [12][1300/2075]  lr: 2.5000e-05  eta: 0:03:37  time: 0.2819  data_time: 0.0056  memory: 3953  loss: 0.5124  loss_rpn_cls: 0.0145  loss_rpn_bbox: 0.0209  s0.loss_cls: 0.1522  s0.acc: 98.6328  s0.loss_bbox: 0.0911  s1.loss_cls: 0.0674  s1.acc: 99.2188  s1.loss_bbox: 0.0834  s2.loss_cls: 0.0331  s2.acc: 99.0234  s2.loss_bbox: 0.0498
# 12/06 09:00:20 - mmengine - INFO - Epoch(train) [12][1350/2075]  lr: 2.5000e-05  eta: 0:03:23  time: 0.2817  data_time: 0.0055  memory: 3953  loss: 0.5158  loss_rpn_cls: 0.0153  loss_rpn_bbox: 0.0211  s0.loss_cls: 0.1582  s0.acc: 90.2344  s0.loss_bbox: 0.0888  s1.loss_cls: 0.0718  s1.acc: 90.3320  s1.loss_bbox: 0.0775  s2.loss_cls: 0.0357  s2.acc: 94.9219  s2.loss_bbox: 0.0474
# 12/06 09:00:34 - mmengine - INFO - Epoch(train) [12][1400/2075]  lr: 2.5000e-05  eta: 0:03:09  time: 0.2815  data_time: 0.0057  memory: 3953  loss: 0.4435  loss_rpn_cls: 0.0139  loss_rpn_bbox: 0.0214  s0.loss_cls: 0.1313  s0.acc: 99.3164  s0.loss_bbox: 0.0751  s1.loss_cls: 0.0597  s1.acc: 99.2188  s1.loss_bbox: 0.0701  s2.loss_cls: 0.0295  s2.acc: 99.8047  s2.loss_bbox: 0.0425
# 12/06 09:00:48 - mmengine - INFO - Epoch(train) [12][1450/2075]  lr: 2.5000e-05  eta: 0:02:55  time: 0.2801  data_time: 0.0053  memory: 3954  loss: 0.4130  loss_rpn_cls: 0.0128  loss_rpn_bbox: 0.0164  s0.loss_cls: 0.1209  s0.acc: 98.8281  s0.loss_bbox: 0.0677  s1.loss_cls: 0.0548  s1.acc: 99.0234  s1.loss_bbox: 0.0677  s2.loss_cls: 0.0295  s2.acc: 99.0234  s2.loss_bbox: 0.0432
# 12/06 09:01:02 - mmengine - INFO - Epoch(train) [12][1500/2075]  lr: 2.5000e-05  eta: 0:02:41  time: 0.2818  data_time: 0.0055  memory: 3953  loss: 0.5184  loss_rpn_cls: 0.0162  loss_rpn_bbox: 0.0271  s0.loss_cls: 0.1531  s0.acc: 99.3164  s0.loss_bbox: 0.0886  s1.loss_cls: 0.0682  s1.acc: 99.7070  s1.loss_bbox: 0.0800  s2.loss_cls: 0.0333  s2.acc: 99.9023  s2.loss_bbox: 0.0520
# 12/06 09:01:16 - mmengine - INFO - Epoch(train) [12][1550/2075]  lr: 2.5000e-05  eta: 0:02:27  time: 0.2822  data_time: 0.0058  memory: 3953  loss: 0.5281  loss_rpn_cls: 0.0159  loss_rpn_bbox: 0.0237  s0.loss_cls: 0.1639  s0.acc: 98.6328  s0.loss_bbox: 0.0860  s1.loss_cls: 0.0746  s1.acc: 99.3164  s1.loss_bbox: 0.0776  s2.loss_cls: 0.0359  s2.acc: 99.9023  s2.loss_bbox: 0.0504
# 12/06 09:01:30 - mmengine - INFO - Epoch(train) [12][1600/2075]  lr: 2.5000e-05  eta: 0:02:13  time: 0.2827  data_time: 0.0059  memory: 3953  loss: 0.4675  loss_rpn_cls: 0.0145  loss_rpn_bbox: 0.0216  s0.loss_cls: 0.1441  s0.acc: 98.6328  s0.loss_bbox: 0.0757  s1.loss_cls: 0.0636  s1.acc: 99.3164  s1.loss_bbox: 0.0709  s2.loss_cls: 0.0318  s2.acc: 98.4375  s2.loss_bbox: 0.0453
# 12/06 09:01:44 - mmengine - INFO - Epoch(train) [12][1650/2075]  lr: 2.5000e-05  eta: 0:01:59  time: 0.2814  data_time: 0.0053  memory: 3952  loss: 0.5012  loss_rpn_cls: 0.0140  loss_rpn_bbox: 0.0196  s0.loss_cls: 0.1539  s0.acc: 93.0664  s0.loss_bbox: 0.0811  s1.loss_cls: 0.0715  s1.acc: 94.5652  s1.loss_bbox: 0.0778  s2.loss_cls: 0.0349  s2.acc: 95.4590  s2.loss_bbox: 0.0483
# 12/06 09:01:58 - mmengine - INFO - Epoch(train) [12][1700/2075]  lr: 2.5000e-05  eta: 0:01:45  time: 0.2811  data_time: 0.0055  memory: 3953  loss: 0.4342  loss_rpn_cls: 0.0131  loss_rpn_bbox: 0.0169  s0.loss_cls: 0.1309  s0.acc: 96.6797  s0.loss_bbox: 0.0708  s1.loss_cls: 0.0570  s1.acc: 96.7773  s1.loss_bbox: 0.0713  s2.loss_cls: 0.0299  s2.acc: 96.1914  s2.loss_bbox: 0.0444
# 12/06 09:02:13 - mmengine - INFO - Epoch(train) [12][1750/2075]  lr: 2.5000e-05  eta: 0:01:31  time: 0.2820  data_time: 0.0055  memory: 3953  loss: 0.4709  loss_rpn_cls: 0.0118  loss_rpn_bbox: 0.0194  s0.loss_cls: 0.1390  s0.acc: 97.2656  s0.loss_bbox: 0.0804  s1.loss_cls: 0.0613  s1.acc: 98.1964  s1.loss_bbox: 0.0781  s2.loss_cls: 0.0318  s2.acc: 95.7447  s2.loss_bbox: 0.0490
# 12/06 09:02:27 - mmengine - INFO - Epoch(train) [12][1800/2075]  lr: 2.5000e-05  eta: 0:01:17  time: 0.2813  data_time: 0.0058  memory: 3953  loss: 0.4366  loss_rpn_cls: 0.0133  loss_rpn_bbox: 0.0185  s0.loss_cls: 0.1267  s0.acc: 97.2656  s0.loss_bbox: 0.0760  s1.loss_cls: 0.0588  s1.acc: 96.2891  s1.loss_bbox: 0.0702  s2.loss_cls: 0.0292  s2.acc: 95.1172  s2.loss_bbox: 0.0438
# 12/06 09:02:41 - mmengine - INFO - Epoch(train) [12][1850/2075]  lr: 2.5000e-05  eta: 0:01:03  time: 0.2825  data_time: 0.0055  memory: 3953  loss: 0.4673  loss_rpn_cls: 0.0155  loss_rpn_bbox: 0.0233  s0.loss_cls: 0.1336  s0.acc: 95.8008  s0.loss_bbox: 0.0782  s1.loss_cls: 0.0612  s1.acc: 95.5078  s1.loss_bbox: 0.0756  s2.loss_cls: 0.0315  s2.acc: 95.0195  s2.loss_bbox: 0.0484
# 12/06 09:02:55 - mmengine - INFO - Epoch(train) [12][1900/2075]  lr: 2.5000e-05  eta: 0:00:49  time: 0.2808  data_time: 0.0057  memory: 3953  loss: 0.4379  loss_rpn_cls: 0.0112  loss_rpn_bbox: 0.0181  s0.loss_cls: 0.1291  s0.acc: 93.2617  s0.loss_bbox: 0.0745  s1.loss_cls: 0.0593  s1.acc: 93.0664  s1.loss_bbox: 0.0720  s2.loss_cls: 0.0293  s2.acc: 94.7266  s2.loss_bbox: 0.0445
# 12/06 09:03:09 - mmengine - INFO - Epoch(train) [12][1950/2075]  lr: 2.5000e-05  eta: 0:00:35  time: 0.2820  data_time: 0.0056  memory: 3953  loss: 0.4792  loss_rpn_cls: 0.0142  loss_rpn_bbox: 0.0224  s0.loss_cls: 0.1437  s0.acc: 98.1445  s0.loss_bbox: 0.0836  s1.loss_cls: 0.0619  s1.acc: 98.7305  s1.loss_bbox: 0.0759  s2.loss_cls: 0.0318  s2.acc: 99.1211  s2.loss_bbox: 0.0457
# 12/06 09:03:23 - mmengine - INFO - Epoch(train) [12][2000/2075]  lr: 2.5000e-05  eta: 0:00:21  time: 0.2840  data_time: 0.0056  memory: 3953  loss: 0.4489  loss_rpn_cls: 0.0140  loss_rpn_bbox: 0.0183  s0.loss_cls: 0.1360  s0.acc: 93.8477  s0.loss_bbox: 0.0746  s1.loss_cls: 0.0645  s1.acc: 93.8124  s1.loss_bbox: 0.0694  s2.loss_cls: 0.0316  s2.acc: 93.4459  s2.loss_bbox: 0.0404
# 12/06 09:03:37 - mmengine - INFO - Epoch(train) [12][2050/2075]  lr: 2.5000e-05  eta: 0:00:07  time: 0.2817  data_time: 0.0057  memory: 3953  loss: 0.4463  loss_rpn_cls: 0.0145  loss_rpn_bbox: 0.0187  s0.loss_cls: 0.1320  s0.acc: 99.4141  s0.loss_bbox: 0.0822  s1.loss_cls: 0.0558  s1.acc: 99.9023  s1.loss_bbox: 0.0723  s2.loss_cls: 0.0272  s2.acc: 99.6094  s2.loss_bbox: 0.0436
# 12/06 09:03:44 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20251206_065814
# 12/06 09:03:44 - mmengine - INFO - Saving checkpoint at 12 epochs
# 12/06 09:03:49 - mmengine - INFO - Epoch(val) [12][ 50/733]    eta: 0:00:39  time: 0.0581  data_time: 0.0036  memory: 3953
# 12/06 09:03:52 - mmengine - INFO - Epoch(val) [12][100/733]    eta: 0:00:36  time: 0.0588  data_time: 0.0028  memory: 897
# 12/06 09:03:55 - mmengine - INFO - Epoch(val) [12][150/733]    eta: 0:00:34  time: 0.0589  data_time: 0.0029  memory: 897
# 12/06 09:03:58 - mmengine - INFO - Epoch(val) [12][200/733]    eta: 0:00:31  time: 0.0595  data_time: 0.0031  memory: 897
# 12/06 09:04:01 - mmengine - INFO - Epoch(val) [12][250/733]    eta: 0:00:28  time: 0.0588  data_time: 0.0029  memory: 897
# 12/06 09:04:04 - mmengine - INFO - Epoch(val) [12][300/733]    eta: 0:00:25  time: 0.0585  data_time: 0.0029  memory: 897
# 12/06 09:04:07 - mmengine - INFO - Epoch(val) [12][350/733]    eta: 0:00:22  time: 0.0592  data_time: 0.0030  memory: 897
# 12/06 09:04:10 - mmengine - INFO - Epoch(val) [12][400/733]    eta: 0:00:19  time: 0.0588  data_time: 0.0029  memory: 897
# 12/06 09:04:13 - mmengine - INFO - Epoch(val) [12][450/733]    eta: 0:00:16  time: 0.0588  data_time: 0.0029  memory: 897
# 12/06 09:04:16 - mmengine - INFO - Epoch(val) [12][500/733]    eta: 0:00:13  time: 0.0588  data_time: 0.0029  memory: 897
# 12/06 09:04:19 - mmengine - INFO - Epoch(val) [12][550/733]    eta: 0:00:10  time: 0.0588  data_time: 0.0028  memory: 897
# 12/06 09:04:22 - mmengine - INFO - Epoch(val) [12][600/733]    eta: 0:00:07  time: 0.0580  data_time: 0.0026  memory: 897
# 12/06 09:04:25 - mmengine - INFO - Epoch(val) [12][650/733]    eta: 0:00:04  time: 0.0583  data_time: 0.0026  memory: 897
# 12/06 09:04:28 - mmengine - INFO - Epoch(val) [12][700/733]    eta: 0:00:01  time: 0.0588  data_time: 0.0028  memory: 897
# 12/06 09:04:30 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.08s).
# Accumulating evaluation results...
# DONE (t=0.21s).
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.178
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=300 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=1000 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.778
# 12/06 09:04:31 - mmengine - INFO - bbox_mAP_copypaste: 0.486 -1.000 -1.000 0.003 0.178 0.558
# 12/06 09:04:31 - mmengine - INFO - Epoch(val) [12][733/733]    coco/bbox_mAP: 0.4860  coco/bbox_mAP_50: -1.0000  coco/bbox_mAP_75: -1.0000  coco/bbox_mAP_s: 0.0030  coco/bbox_mAP_m: 0.1780  coco/bbox_mAP_l: 0.5580  data_time: 0.0029  time: 0.0587
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 12/06 09:04:35 - mmengine - INFO - Epoch(test) [ 50/733]    eta: 0:00:41  time: 0.0605  data_time: 0.0048  memory: 897
# 12/06 09:04:38 - mmengine - INFO - Epoch(test) [100/733]    eta: 0:00:37  time: 0.0579  data_time: 0.0028  memory: 897
# 12/06 09:04:40 - mmengine - INFO - Epoch(test) [150/733]    eta: 0:00:34  time: 0.0579  data_time: 0.0027  memory: 897
# 12/06 09:04:43 - mmengine - INFO - Epoch(test) [200/733]    eta: 0:00:31  time: 0.0580  data_time: 0.0028  memory: 897
# 12/06 09:04:46 - mmengine - INFO - Epoch(test) [250/733]    eta: 0:00:28  time: 0.0578  data_time: 0.0027  memory: 897
# 12/06 09:04:49 - mmengine - INFO - Epoch(test) [300/733]    eta: 0:00:25  time: 0.0585  data_time: 0.0027  memory: 897
# 12/06 09:04:52 - mmengine - INFO - Epoch(test) [350/733]    eta: 0:00:22  time: 0.0582  data_time: 0.0028  memory: 897
# 12/06 09:04:55 - mmengine - INFO - Epoch(test) [400/733]    eta: 0:00:19  time: 0.0581  data_time: 0.0028  memory: 897
# 12/06 09:04:58 - mmengine - INFO - Epoch(test) [450/733]    eta: 0:00:16  time: 0.0583  data_time: 0.0028  memory: 897
# 12/06 09:05:01 - mmengine - INFO - Epoch(test) [500/733]    eta: 0:00:13  time: 0.0579  data_time: 0.0029  memory: 897
# 12/06 09:05:04 - mmengine - INFO - Epoch(test) [550/733]    eta: 0:00:10  time: 0.0579  data_time: 0.0028  memory: 897
# 12/06 09:05:07 - mmengine - INFO - Epoch(test) [600/733]    eta: 0:00:07  time: 0.0592  data_time: 0.0030  memory: 897
# 12/06 09:05:10 - mmengine - INFO - Epoch(test) [650/733]    eta: 0:00:04  time: 0.0589  data_time: 0.0029  memory: 897
# 12/06 09:05:13 - mmengine - INFO - Epoch(test) [700/733]    eta: 0:00:01  time: 0.0587  data_time: 0.0028  memory: 897
# 12/06 09:05:15 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.34s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.85s).
# Accumulating evaluation results...
# DONE (t=0.21s).
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.178
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=300 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=1000 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.778
# 12/06 09:05:16 - mmengine - INFO - bbox_mAP_copypaste: 0.486 -1.000 -1.000 0.003 0.178 0.558
# 12/06 09:05:16 - mmengine - INFO - Epoch(test) [733/733]    coco/bbox_mAP: 0.4860  coco/bbox_mAP_50: -1.0000  coco/bbox_mAP_75: -1.0000  coco/bbox_mAP_s: 0.0030  coco/bbox_mAP_m: 0.1780  coco/bbox_mAP_l: 0.5580  data_time: 0.0029  time: 0.0584
# val metrics: {'coco/bbox_mAP': 0.486, 'coco/bbox_mAP_50': -1.0, 'coco/bbox_mAP_75': -1.0, 'coco/bbox_mAP_s': 0.003, 'coco/bbox_mAP_m': 0.178, 'coco/bbox_mAP_l': 0.558}
# 학습 완료. work_dir: /data/ephemeral/home/model/work_dirs_single/cascade_rcnn_r50_1024_single

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
